# %%
import pandas as pd
import numpy as np
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize
from sklearn.model_selection import train_test_split
import re,string,unicodedata
from nltk.tokenize.toktok import ToktokTokenizer

# %%
df = pd.read_csv('Amazon_Unlocked_Mobile.csv')
df.head(10)
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 6  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 7  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 8  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 9  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0
# 5       1  I already had a phone with problems... I know ...           1.0
# 6       2  The charging port was loose. I got that solder...           0.0
# 7       2  Phone looks good but wouldn't stay charged, ha...           0.0
# 8       5  I originally was using the Samsung S2 Galaxy f...           0.0
# 9       3  It's battery life is great. It's very responsi...           0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413840 entries, 0 to 413839
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Product Name  413840 non-null  object
#  1   Brand Name    348669 non-null  object
#  2   Price         407907 non-null  float64
#  3   Rating        413840 non-null  int64
#  4   Reviews       413778 non-null  object
#  5   Review Votes  401544 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 18.9+ MB

# %%
#Creating a copy
process_reviews=df.copy()

# %%
#Figuring out the distribution of categories
process_reviews['Rating'].value_counts()
# Out:
# 5    223605
# 1     72350
# 4     61392
# 3     31765
# 2     24728
# Name: Rating, dtype: int64

# %%
process_reviews['Brand Name'].value_counts()
# Out:
# Samsung         65747
# BLU             63248
# Apple           58186
# LG              22417
# BlackBerry      16872
#                 ...
# M-HORSE             1
# ToShare Tech        1
# LeEco               1
# Danger Inc.         1
# Concox              1
# Name: Brand Name, Length: 384, dtype: int64

# %%
#Checking for null values
process_reviews.isnull().sum()
# Out:
# Product Name        0
# Brand Name      65171
# Price            5933
# Rating              0
# Reviews            62
# Review Votes    12296
# dtype: int64

# %%
clean_reviews=process_reviews.copy()
def review_cleaning(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

# %%
process_reviews['Reviews']=process_reviews['Reviews'].apply(lambda x:review_cleaning(x))
process_reviews.head(10)
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 6  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 7  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 8  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 9  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  i feel so lucky to have found this used phone ...           1.0
# 1       4  nice phone nice up grade from my pantach revue...           0.0
# 2       5                                       very pleased           0.0
# 3       4  it works good but it goes slow sometimes but i...           0.0
# 4       4  great phone to replace my lost phone the only ...           0.0
# 5       1  i already had a phone with problems i know it ...           1.0
# 6       2  the charging port was loose i got that soldere...           0.0
# 7       2  phone looks good but wouldnt stay charged had ...           0.0
# 8       5  i originally was using the samsung  galaxy for...           0.0
# 9       3  its battery life is great its very responsive ...           0.0

# %%
#Tokenization of text
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer=ToktokTokenizer()

#Setting English stopwords
stopword_list=nltk.corpus.stopwords.words('english')

# %%
#set stopwords to english
from nltk.corpus import stopwords

stop=set(stopwords.words('english'))
print(stop)

#removing the stopwords
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text


#Apply function on review column
process_reviews['Reviews'] = process_reviews['Reviews'].apply(remove_stopwords)
process_reviews.head(10)
# Out:
# {'off', "won't", "it's", 'can', 'didn', 'a', 'not', 'wasn', 'into', 'why', 'she', 'again', 'mustn', 'your', 'herself', "you're", 'against', 'mightn', "you'd", 'o', 'further', "she's", 'over', 'but', "wouldn't", 'we', 'has', 'before', 'below', 'weren', 're', 'where', "don't", "shan't", 'aren', 'had', "aren't", "needn't", 'more', 'our', 'own', 'how', 'only', "doesn't", 'his', 'won', 'wouldn', 'same', 'doing', 'while', 'hadn', 'have', 'few', "hadn't", 'haven', "shouldn't", "you'll", 'be', 'out', 'having', 'some', 'shouldn', 'should', 'yourselves', 'itself', 'as', 'all', 'for', 'and', 'hers', 'its', 'did', 'which', 'during', 'from', 'been', 'too', "haven't", 'me', 'was', 'what', "wasn't", 'ourselves', 'at', 'when', 'then', 'theirs', 'between', 'themselves', 'doesn', 'through', 'y', 'needn', 'her', 'there', "hasn't", 'am', 'they', 'that', 'no', 'isn', 'my', 'are', 'them', 'll', 'to', "mightn't", 'ain', "that'll", 'on', 'myself', 'an', 'were', 'yourself', 'their', 'in', 'just', 'most', 'himself', 'about', 'ours', 'each', "didn't", 'does', 'do', "isn't", 'of', "mustn't", 'don', 'shan', "weren't", 's', "you've", "couldn't", 'd', 'this', 'those', 'you', 'is', 'if', 'until', 'such', 'm', 'ma', 'other', 'because', 'above', 'it', 'with', 'here', 'will', 've', 'nor', 'after', 'him', 'so', 'than', 'i', 'who', 'up', 'down', 'now', 'he', 'couldn', "should've", 'whom', 'these', 'the', 'any', 't', 'both', 'being', 'hasn', 'under', 'very', 'once', 'or', 'yours', 'by'}
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 6  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 7  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 8  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 9  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  feel lucky found used phone us used hard phone...           1.0
# 1       4  nice phone nice grade pantach revue clean set ...           0.0
# 2       5                                            pleased           0.0
# 3       4     works good goes slow sometimes good phone love           0.0
# 4       4  great phone replace lost phone thing volume bu...           0.0
# 5       1  already phone problems know stated used dang s...           1.0
# 6       2  charging port loose got soldered needed new ba...           0.0
# 7       2  phone looks good wouldnt stay charged buy new ...           0.0
# 8       5  originally using samsung galaxy sprint wanted ...           0.0
# 9       3  battery life great responsive touch issue some...           0.0

# %%
#Stemming the text

def simple_stemmer(text):
    ps=nltk.porter.PorterStemmer()
    text= ' '.join([ps.stem(word) for word in text.split()])
    return text

#Apply function on review column
process_reviews['Reviews'] = process_reviews['Reviews'].apply(simple_stemmer)
process_reviews.head(10)
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 6  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 7  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 8  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 9  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  feel lucki found use phone us use hard phone l...           1.0
# 1       4  nice phone nice grade pantach revu clean set e...           0.0
# 2       5                                              pleas           0.0
# 3       4         work good goe slow sometim good phone love           0.0
# 4       4  great phone replac lost phone thing volum butt...           0.0
# 5       1  alreadi phone problem know state use dang stat...           1.0
# 6       2  charg port loos got solder need new batteri we...           0.0
# 7       2  phone look good wouldnt stay charg buy new bat...           0.0
# 8       5  origin use samsung galaxi sprint want return b...           0.0
# 9       3  batteri life great respons touch issu sometim ...           0.0

# %%
def f(row):
    
    '''This function returns sentiment value based on the overall ratings from the user'''
    
    if row['Rating'] == 3.0:
        val = 'Neutral'
    elif row['Rating'] == 1.0 or row['Rating'] == 2.0:
        val = 'Negative'
    elif row['Rating'] == 4.0 or row['Rating'] == 5.0:
        val = 'Positive'
    else:
        val = -1
    return val

# %%
#Applying the function in our new column
process_reviews['sentiment'] = process_reviews.apply(f, axis=1)
process_reviews.head(10)
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 6  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 7  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 8  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 9  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes  \
# 0       5  feel lucki found use phone us use hard phone l...           1.0
# 1       4  nice phone nice grade pantach revu clean set e...           0.0
# 2       5                                              pleas           0.0
# 3       4         work good goe slow sometim good phone love           0.0
# 4       4  great phone replac lost phone thing volum butt...           0.0
# 5       1  alreadi phone problem know state use dang stat...           1.0
# 6       2  charg port loos got solder need new batteri we...           0.0
# 7       2  phone look good wouldnt stay charg buy new bat...           0.0
# 8       5  origin use samsung galaxi sprint want return b...           0.0
# 9       3  batteri life great respons touch issu sometim ...           0.0
#
#   sentiment
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Positive
# 5  Negative
# 6  Negative
# 7  Negative
# 8  Positive
# 9   Neutral

# %%
process_reviews['sentiment'].value_counts()
# Out:
# Positive    284997
# Negative     97078
# Neutral      31765
# Name: sentiment, dtype: int64
